# %% [markdown]
# HELLO COLAB

# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %%
# !pip install numpy

# %%
import numpy as np
np.__version__
# Out:
# '1.19.5'
